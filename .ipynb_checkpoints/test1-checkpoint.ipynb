# %%
import pandas as pd

df = pd.read_excel(r'E:/cj1571.xlsx')
df.shape
# Out:
# (30, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UID            30 non-null     int64
#  1   课程ID           30 non-null     int64
#  2   课程名称           30 non-null     object
#  3   学生姓名           30 non-null     object
#  4   学号/工号          30 non-null     int64
#  5   学校             30 non-null     object
#  6   院系id           30 non-null     int64
#  7   院系             30 non-null     object
#  8   专业             30 non-null     object
#  9   班级             30 non-null     object
#  10  入学年份           30 non-null     int64
#  11  课程视频得分(25%)    30 non-null     float64
#  12  课程视频进度         30 non-null     object
#  13  课程测验得分(15%)    30 non-null     float64
#  14  课程测验进度         30 non-null     object
#  15  作业得分(20%)      30 non-null     float64
#  16  章节学习次数得分(10%)  30 non-null     float64
# ...

# %%
df.isnull()
# Out:
#       UID   课程ID   课程名称   学生姓名  学号/工号     学校   院系id     院系     专业     班级  ...  \
# 0   False  False  False  False  False  False  False  False  False  False  ...
# 1   False  False  False  False  False  False  False  False  False  False  ...
# 2   False  False  False  False  False  False  False  False  False  False  ...
# 3   False  False  False  False  False  False  False  False  False  False  ...
# 4   False  False  False  False  False  False  False  False  False  False  ...
# 5   False  False  False  False  False  False  False  False  False  False  ...
# 6   False  False  False  False  False  False  False  False  False  False  ...
# 7   False  False  False  False  False  False  False  False  False  False  ...
# 8   False  False  False  False  False  False  False  False  False  False  ...
# 9   False  False  False  False  False  False  False  False  False  False  ...
# 10  False  False  False  False  False  False  False  False  False  False  ...
# ...

# %%
df1 = df[['课程名称', '学生姓名', '学号/工号', '班级', '课程视频得分(25%)','课程测验得分(15%)','作业得分(20%)','章节学习次数得分(10%)',
          '签到得分(10%)','线下得分(20%)','综合成绩','五级制等级（ABCDE）']]
df1
# Out:
#             课程名称 学生姓名       学号/工号            班级  课程视频得分(25%)  课程测验得分(15%)  \
# 0   嵌入式技术（STM32）  陈子然  5201500101  电子信息（内培）1571         0.00         0.00
# 1   嵌入式技术（STM32）  赵子剑  5201500106  电子信息（内培）1571         0.00         0.00
# 2   嵌入式技术（STM32）  朱东润  5201500717  电子信息（内培）1571         0.00         0.00
# 3   嵌入式技术（STM32）   王栋  5201500718  电子信息（内培）1571         0.68         0.00
# 4   嵌入式技术（STM32）  王宇伦  5201501207  电子信息（内培）1571         2.03         0.00
# 5   嵌入式技术（STM32）   闫阅  5201501223  电子信息（内培）1571         7.43         7.16
# 6   嵌入式技术（STM32）  葛瀚翼  5201501302  电子信息（内培）1571         0.00         0.00
# 7   嵌入式技术（STM32）   王贺  5201501306  电子信息（内培）1571         0.68         0.00
# 8   嵌入式技术（STM32）  张睿辰  5201501322  电子信息（内培）1571         2.03         0.00
# 9   嵌入式技术（STM32）  吕玲秀  5201501324  电子信息（内培）1571         0.00         3.38
# 10  嵌入式技术（STM32）   张添  5201501327  电子信息（内培）1571         1.35         0.00
# 11  嵌入式技术（STM32）  刘雨典  5201501405  电子信息（内培）1571         5.41        13.06
# ...

# %%
df2 =  df1.loc[df1['课程视频得分(25%)'] == 0].loc[df1['作业得分(20%)'] == 0]     # 筛选视频为0和作业为0

# %%
df2
# Out:
#             课程名称 学生姓名       学号/工号            班级  课程视频得分(25%)  课程测验得分(15%)  \
# 1   嵌入式技术（STM32）  赵子剑  5201500106  电子信息（内培）1571          0.0         0.00
# 6   嵌入式技术（STM32）  葛瀚翼  5201501302  电子信息（内培）1571          0.0         0.00
# 9   嵌入式技术（STM32）  吕玲秀  5201501324  电子信息（内培）1571          0.0         3.38
# 24  嵌入式技术（STM32）  张绍臻  5201501703  电子信息（内培）1571          0.0         0.00
# 25  嵌入式技术（STM32）   张昊  5201501713  电子信息（内培）1571          0.0         0.00
# 29  嵌入式技术（STM32）  孙社文        1294            其他          0.0         0.00
#
#     作业得分(20%)  章节学习次数得分(10%)  签到得分(10%)  线下得分(20%)   综合成绩 五级制等级（ABCDE）
# 1         0.0           0.10       6.67        0.0   6.77            E
# 6         0.0           0.57       8.00        0.0   8.57            E
# 9         0.0           0.20       8.00        0.0  11.58            E
# 24        0.0           0.07       7.67        0.0   7.74            E
# 25        0.0           0.27       6.67        0.0   6.94            E
# ...

# %%
df3 = df2.iloc[:,4:10]       #提取所有行中4-9列
df3
# Out:
#     课程视频得分(25%)  课程测验得分(15%)  作业得分(20%)  章节学习次数得分(10%)  签到得分(10%)  线下得分(20%)
# 1           0.0         0.00        0.0           0.10       6.67        0.0
# 6           0.0         0.00        0.0           0.57       8.00        0.0
# 9           0.0         3.38        0.0           0.20       8.00        0.0
# 24          0.0         0.00        0.0           0.07       7.67        0.0
# 25          0.0         0.00        0.0           0.27       6.67        0.0
# 29          0.0         0.00        0.0           0.03       0.00        0.0

# %%
df3.sum(axis=1)        #计算所有行和  axis=0 表示列和，axis=1表示行和
# Out:
# 1      6.77
# 6      8.57
# 9     11.58
# 24     7.74
# 25     6.94
# 29     0.03
# dtype: float64

# %%
df.drop(df.columns[3], axis=1, inplace=True)       # 删除第3列
df
# Out:
#             课程名称 学生姓名       学号/工号            班级  入学年份  课程视频得分(25%) 课程视频进度  \
# 0   嵌入式技术（STM32）  陈子然  5201500101  电子信息（内培）1571     0         0.00   0/37
# 1   嵌入式技术（STM32）  赵子剑  5201500106  电子信息（内培）1571     0         0.00   0/37
# 2   嵌入式技术（STM32）  朱东润  5201500717  电子信息（内培）1571     0         0.00   0/37
# 3   嵌入式技术（STM32）   王栋  5201500718  电子信息（内培）1571     0         0.68   1/37
# 4   嵌入式技术（STM32）  王宇伦  5201501207  电子信息（内培）1571     0         2.03   3/37
# 5   嵌入式技术（STM32）   闫阅  5201501223  电子信息（内培）1571     0         7.43  11/37
# 6   嵌入式技术（STM32）  葛瀚翼  5201501302  电子信息（内培）1571     0         0.00   0/37
# 7   嵌入式技术（STM32）   王贺  5201501306  电子信息（内培）1571     0         0.68   1/37
# 8   嵌入式技术（STM32）  张睿辰  5201501322  电子信息（内培）1571     0         2.03   3/37
# 9   嵌入式技术（STM32）  吕玲秀  5201501324  电子信息（内培）1571     0         0.00   0/37
# 10  嵌入式技术（STM32）   张添  5201501327  电子信息（内培）1571     0         1.35   2/37
# 11  嵌入式技术（STM32）  刘雨典  5201501405  电子信息（内培）1571     0         5.41   8/37
# ...

# %%
data = df3.sum(axis = 1)
data
# Out:
# 1      6.77
# 6      8.57
# 9     11.58
# 24     7.74
# 25     6.94
# 29     0.03
# dtype: float64

# %%
df3['综合成绩'] = data      #在表右侧添加一列名：综合成绩
df3
# Out:
#     课程视频得分(25%)  课程测验得分(15%)  作业得分(20%)  章节学习次数得分(10%)  签到得分(10%)  线下得分(20%)  \
# 1           0.0         0.00        0.0           0.10       6.67        0.0
# 6           0.0         0.00        0.0           0.57       8.00        0.0
# 9           0.0         3.38        0.0           0.20       8.00        0.0
# 24          0.0         0.00        0.0           0.07       7.67        0.0
# 25          0.0         0.00        0.0           0.27       6.67        0.0
# 29          0.0         0.00        0.0           0.03       0.00        0.0
#
#      综合成绩
# 1    6.77
# 6    8.57
# 9   11.58
# 24   7.74
# 25   6.94
# 29   0.03

# %%
df.drop(df.columns[6], axis=1, inplace=True)       # 删除第3列
df
# Out:
#             课程名称 学生姓名       学号/工号            班级  课程视频得分(25%)  课程测验得分(15%)  \
# 0   嵌入式技术（STM32）  陈子然  5201500101  电子信息（内培）1571         0.00         0.00
# 1   嵌入式技术（STM32）  赵子剑  5201500106  电子信息（内培）1571         0.00         0.00
# 2   嵌入式技术（STM32）  朱东润  5201500717  电子信息（内培）1571         0.00         0.00
# 3   嵌入式技术（STM32）   王栋  5201500718  电子信息（内培）1571         0.68         0.00
# 4   嵌入式技术（STM32）  王宇伦  5201501207  电子信息（内培）1571         2.03         0.00
# 5   嵌入式技术（STM32）   闫阅  5201501223  电子信息（内培）1571         7.43         7.16
# 6   嵌入式技术（STM32）  葛瀚翼  5201501302  电子信息（内培）1571         0.00         0.00
# 7   嵌入式技术（STM32）   王贺  5201501306  电子信息（内培）1571         0.68         0.00
# 8   嵌入式技术（STM32）  张睿辰  5201501322  电子信息（内培）1571         2.03         0.00
# 9   嵌入式技术（STM32）  吕玲秀  5201501324  电子信息（内培）1571         0.00         3.38
# 10  嵌入式技术（STM32）   张添  5201501327  电子信息（内培）1571         1.35         0.00
# 11  嵌入式技术（STM32）  刘雨典  5201501405  电子信息（内培）1571         5.41        13.06
# ...

# %%
df.drop(df.columns[10], axis=1, inplace=True)       # 删除第3列
df
# Out:
#             课程名称 学生姓名       学号/工号            班级  课程视频得分(25%)  课程测验得分(15%)  \
# 0   嵌入式技术（STM32）  陈子然  5201500101  电子信息（内培）1571         0.00         0.00
# 1   嵌入式技术（STM32）  赵子剑  5201500106  电子信息（内培）1571         0.00         0.00
# 2   嵌入式技术（STM32）  朱东润  5201500717  电子信息（内培）1571         0.00         0.00
# 3   嵌入式技术（STM32）   王栋  5201500718  电子信息（内培）1571         0.68         0.00
# 4   嵌入式技术（STM32）  王宇伦  5201501207  电子信息（内培）1571         2.03         0.00
# 5   嵌入式技术（STM32）   闫阅  5201501223  电子信息（内培）1571         7.43         7.16
# 6   嵌入式技术（STM32）  葛瀚翼  5201501302  电子信息（内培）1571         0.00         0.00
# 7   嵌入式技术（STM32）   王贺  5201501306  电子信息（内培）1571         0.68         0.00
# 8   嵌入式技术（STM32）  张睿辰  5201501322  电子信息（内培）1571         2.03         0.00
# 9   嵌入式技术（STM32）  吕玲秀  5201501324  电子信息（内培）1571         0.00         3.38
# 10  嵌入式技术（STM32）   张添  5201501327  电子信息（内培）1571         1.35         0.00
# 11  嵌入式技术（STM32）  刘雨典  5201501405  电子信息（内培）1571         5.41        13.06
# ...
